# %%
import json
import glob
import pandas as pd
import requests

# %%
cache = {}
def id2name(q):
    q = q.upper()
    if q in cache:
        return cache[q]
    url = 'https://www.wikidata.org/w/api.php?action=wbgetentities&props=labels&ids=%s&languages=en&format=json' % q
    resp = requests.get(url)
    v = resp.json()['entities'][q]['labels']['en']['value']
    cache[q] = v
    return v

# %%
files = glob.glob("extractions/part-*")
data = []
for path in files:
    with open(path) as file:
        lines = file.readlines()
        data.extend([json.loads(l) for l in lines])

# %%
EVAL_NUM = 100
EVAL_REL = 'P19'

# %%
df = pd.DataFrame.from_records(data)
#df.sort_values('probability', ascending=False, inplace=True)

# %%
df = df[df['predictedPredicate'] == EVAL_REL]

# %%
obj_names = [id2name(q) for q in df[:EVAL_NUM]['obj']]
sub_names = [id2name(q) for q in df[:EVAL_NUM]['subject']]

# %%
df_obj = pd.DataFrame(obj_names, index=df[:EVAL_NUM].index, columns=['obj_name'])
df_sub = pd.DataFrame(sub_names, index=df[:EVAL_NUM].index, columns=['sub_name'])
df = df.join(df_sub).join(df_obj)

# %%
subset = df[:EVAL_NUM][['sub_name','obj_name', 'sentence','probability']]
subset.to_csv(EVAL_REL + '.csv')
subset
# Out:
#                        sub_name  \
# 0                    Dany Saval
# 1                   Rick Brewer
# 2                       Stanley
# 4                   archaeology
# 5                       Tallinn
# 7                 German Empire
# 8                    Lee Wilkie
# 9               Catholic bishop
# 10                        Bursa
# 11                       Narada
# 12            Ranmore Martinesz
# 13                   Mary Kenny
# 14                        Greek
# 15                        Greek
# 16                   Elso Brito
# 17                       Guymon
# 18                 Gordon Grice
# 19                   Bhanushali
# 21                    Prishtina
# 22                      Tauragė
# 23                       Arabic
# 24                   Jacky Novi
# 25                    Mike Cope
# 26                  Mikko Luoma
# 27                Rainer Arnold
# 28            Lindsey Durlacher
# 29                  Frank Swart
# 30                  Frank Swart
# 32   Maria Christina of Austria
# 33                    Wolfsberg
# ..                          ...
# 81                        Toruń
# 82               Zsolt Szilágyi
# 83                  Perry Pearn
# 84                       Dublin
# 85                Ingrid Lieten
# 86                Paul Nicholas
# 87                 Géza Fazakas
# 88                       France
# 89              Robbie Dennison
# 90          Dimitris Giannoulis
# 91                  Chuck Hulse
# 92                Daniel Klewer
# 93                  Mark Coogan
# 94                    Manhasset
# 95               Robert McNeill
# 96               Robert McNeill
# 97            Brendan Augustine
# 98                      Chicago
# 99               Patti Reynolds
# 100       Rotherham United F.C.
# 102      Hockley, West Midlands
# 104          Patric Della Rossa
# 105              Luciano Chessa
# 106                    Chingola
# 107                     Avignon
# 108      Samuel Friedrich Brenz
# 110                   Rolf Graf
# 111                   Cape Town
# 112         Matthew Friedberger
# 113             Sergio Mariotti
#
#                                           obj_name  \
# 0                                           French
# 1                                          Stanley
# 2                                    New Brunswick
# 4                                          England
# 5                                         Estonian
# 7                                           German
# 8                             Dundee Football Club
# 9                                       Evansville
# 10                                         Turkish
# 11                                         Bristol
# 12                                       Sri Lanka
# 13                                    Irish people
# 14                                          Athens
# 15                                          Athens
# 16                                     Netherlands
# 17                        United States of America
# 18                                          Guymon
# 19                                   Indian cinema
# 21                                          Kosovo
# 22                Wrestling at the Summer Olympics
# 23                        Prime Minister of Jordan
# 24                                          French
# 25                        United States of America
# 26                                         Finnish
# 27                                          German
# 28                        United States of America
# 29                                          Boston
# 30                                          Boston
# 32                                        Medellín
# 33                                  Langenzersdorf
# ..                                             ...
# 81   Individual Speedway Junior World Championship
# 82        Hungarian People's Party of Transylvania
# 83                                          Canada
# 84                    European Rugby Champions Cup
# 85                                        Flemings
# 86                                         Croydon
# 87                                     Soproni VSE
# 88                                     Celtic F.C.
# 89                                       Banbridge
# 90                                   Pierikos F.C.
# 91                                         Anaheim
# 92                              F.C. Hansa Rostock
# 93                                       Manhasset
# 94                        United States of America
# 95                                         Glasgow
# 96                                         Glasgow
# 97                                     East London
# 98                                         Playboy
# 99                                         Chicago
# 100                       West Riding of Yorkshire
# 102                                     Birmingham
# 104                                      EHC Olten
# 105                                        Sassari
# 106                                         Zambia
# 107                       F.C. Sochaux-Montbéliard
# 108                                   antisemitism
# 110                                   Randi Hansen
# 111             South Africa national cricket team
# 112                                       Oak Park
# 113                                        Italian
#
#                                               sentence  probability
# 0    Dany Saval (born Danielle Nadine Suzanne Saval...     0.941625
# 1    Rick Brewer (born in Stanley, New Brunswick) i...     0.874904
# 2    Rick Brewer (born in Stanley, New Brunswick) i...     0.851612
# 4    Kenneth Anderson Kitchen (born in 1932 in Aber...     0.926087
# 5    Vitali Teleš (born 17 October 1983 in Tallinn)...     0.933681
# 7    Adolf "Adi" Dassler (born 3 November 1900 in H...     0.889520
# 8    Lee Wilkie (born 20 April 1980 in Dundee) is a...     0.941330
# 9    Francis Raymond Shea served as the third Roman...     0.859180
# 10   Olgun Şimşek (born 1971 in Yenice, Bursa) is a...     0.936877
# 11   Narada Michael Bernard (born 30 November 1981 ...     0.961209
# 12   Ranmore Etholson John Martinesz (born 24 June ...     0.922670
# 13   Mary Kenny (born 4 April 1944, Dublin, Ireland...     0.918412
# 14   Nikolaos Argyriou (Greek: Νικόλαος Αργυρίου) (...     0.932172
# 15   Nikolaos Argyriou (Greek: Νικόλαος Αργυρίου) (...     0.863067
# 16   Elso Brito (born 2 April 1994 in Rotterdam) is...     0.938552
# 17   Gordon Grice (born 1965, Guymon, Oklahoma) is ...     0.946990
# 18   Gordon Grice (born 1965, Guymon, Oklahoma) is ...     0.914877
# 19   Deepak Bhanushali (born 6 September 1971, Mumb...     0.919835
# 21   Gazmend Pula (born in Pristina, Yugoslavia) is...     0.869943
# 22   Mindaugas Ežerskis (born August 2, 1977 in Tau...     0.937986
# 23   Zaid al-Rifai (Arabic: زيد الرفاعي‎) (born 27 ...     0.922909
# 24   Jacques Novi (born 18 July 1946 in Bellegarde,...     0.940143
# 25   Mike Cope (born May 8, 1962 in Pinellas Park, ...     0.934537
# 26   Mikko Luoma (born (1976-06-22) June 22, 1976 i...     0.874610
# 27   Rainer Arnold (born 21 June 1950 in Stuttgart)...     0.958061
# 28   Lindsey Durlacher (September 14, 1974 – June 4...     0.888789
# 29   Frank Swart (born in Boston, Massachusetts, US...     0.900688
# 30   Frank Swart (born in Boston, Massachusetts, US...     0.923872
# 32   Danna Maria García Osuna (born February 4, 197...     0.906017
# 33   Franz Novak (born 10 January 1913 in Wolfsberg...     0.930547
# ..                                                 ...          ...
# 81   Adrian Miedziński (born 20 August 1985 in Toru...     0.933975
# 82   Zsolt Szilágyi (Hungarian pronunciation: [ˈʒol...     0.900800
# 83   Perry Pearn (born June 6, 1951 in Stettler, Al...     0.963679
# 84   Shane Jennings (born 8 July 1981 in Dublin) is...     0.949549
# 85   Ingrid Lieten (born 20 April 1964, Hasselt) is...     0.948714
# 86   Paul Nicholas Denny (born 5 September 1957 in ...     0.956844
# 87   Géza Fazakas (born 18 January 1990 in Budapest...     0.921589
# 88   Stephane Bonnes (born February 26, 1978 in Mul...     0.944284
# 89   Robert "Robbie" Dennison (born April 30, 1963 ...     0.947029
# 90   Dimitris Giannoulis (Greek: Δημήτρης Γιαννούλη...     0.934528
# 91   Chuck Hulse (born October 3, 1927, Anaheim, Ca...     0.930239
# 92   Daniel Klewer (born 4 March 1977 in Rostock, E...     0.895572
# 93   Mark Coogan (born May 1, 1966 in Manhasset, Ne...     0.905143
# 94   Mark Coogan (born May 1, 1966 in Manhasset, Ne...     0.929688
# 95   Robert McNeill (born c. 1868 in Glasgow, Scotl...     0.955462
# 96   Robert McNeill (born c. 1868 in Glasgow, Scotl...     0.890138
# 97   Brendan Augustine (born 26 November 1971 in Ea...     0.909488
# 98   Patti Reynolds (born May 28, 1948 in Chicago, ...     0.920213
# 99   Patti Reynolds (born May 28, 1948 in Chicago, ...     0.960529
# 100  Dean Andrews (born 6 August 1963 in Rotherham,...     0.879396
# 102  Hockley is a central inner-city district in th...     0.873217
# 104  Patric Della Rossa (born July 28, 1975 in Wint...     0.959101
# 105  Luciano Chessa (born 1971, Sassari, Italy) is ...     0.891517
# 106  Felix Mumba Sunzu (born 2 May 1989 in Chingola...     0.898420
# 107  Teddy Richert (born 21 September 1974 in Avign...     0.949225
# 108  Samuel Friedrich Brenz (born in Osterburg, Bav...     0.880611
# 110  Rolf Graf (born 28 April 1960 in Oslo, Norway ...     0.864274
# 111  Ryan Canning (born 22 February 1984 in Cape To...     0.922037
# 112  Matthew Friedberger (born October 21, 1972 in ...     0.924841
# 113  Sergio Mariotti (born August 10, 1946 in Flore...     0.959055
#
# [100 rows x 4 columns]

# %%
df
